# %%
from textblob import TextBlob
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize, sent_tokenize
import matplotlib.pyplot as plt

texto = [
    "I hate it. Doesn't work at all.",
    "Fantastic christmas present",
    "It looks very realistic.",
    "A lovely accessory for the room.",
    "I really like this lamp.",
    "This lamp is a bit difficult to install.",
    "Cute lamp for a child's room.",
    "A very nice lamp.",
    "This lamp is absolutely beautiful!",
]

positivo = 0
negativo = 0
neutral = 0

for textos in texto:
    sentimiento = TextBlob(textos).sentiment.polarity
    print(f"{textos}")

    
    if sentimiento > 0:
        print("Sentimiento positivo\n")
        positivo += 1
    elif sentimiento < 0:
        print("Sentimiento negativo\n")
        negativo += 1
    else:
        print("Sentimiento neutral\n")
        neutral += 1
# Out:
# I hate it. Doesn't work at all.
# Sentimiento negativo
#
# Fantastic christmas present
# Sentimiento positivo
#
# It looks very realistic.
# Sentimiento positivo
#
# A lovely accessory for the room.
# Sentimiento positivo
#
# I really like this lamp.
# Sentimiento positivo
#
# This lamp is a bit difficult to install.
# Sentimiento negativo
#
# Cute lamp for a child's room.
# Sentimiento positivo
#
# A very nice lamp.
# Sentimiento positivo
#
# This lamp is absolutely beautiful!
# Sentimiento positivo
# [nltk_data] Downloading package punkt_tab to /Users/paola/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
